# %%
# Imports
import pandas as pd
from pathlib import Path

# %%
# Load dataset (if available)
csv_path = Path('training/data/creditcard.csv')
if not csv_path.exists():
    raise FileNotFoundError('Place creditcard.csv under training/data first.')
df = pd.read_csv(csv_path)
df.head()

# %%
# Basic stats
df.describe(include='all').T.head(15)

# %%
# Class balance
df['Class'].value_counts(normalize=True).rename({0: 'non-fraud', 1: 'fraud'})
